# %% [markdown]
# # Cows and bulls
#
# Date: 02/14/2024.
# From: Practice Python.
# Link to [exercise](https://www.practicepython.org/exercise/2014/07/05/18-cows-and-bulls.html).
#
# ### Description
#
# Create a program that will play the “cows and bulls” game with the user. The game works like this:
#
# Randomly generate a 4-digit number. Ask the user to guess a 4-digit number. For every digit that the user guessed correctly *in the correct place*, they have a “cow”. For every digit the user guessed correctly *in the wrong place* is a “bull.” Every time the user makes a guess, tell them how many “cows” and “bulls” they have. Once the user guesses the correct number, the game is over. Keep track of the number of guesses the user makes throughout the game and tell the user at the end.
#
# Say the number generated by the computer is 1038. An example interaction could look like this:
#
# ```
#   Welcome to the Cows and Bulls Game!
#   Enter a number:
#   >>> 1234
#   2 cows, 0 bulls
#   >>> 1256
#   1 cow, 1 bull
#   ...
# ```
#
# Until the user guesses the number.
#
# ### My solution

# %%
from random import randint

number = randint(1000, 9999)

print("Welcome to the Cows and Bulls Game!")
guess = int(input("Enter a number: "))
guesses_count = 1

while guess != number:
    cows_list = []
    cows = 0
    bulls = 0
    number_str = str(number)
    guess = str(guess)
    for i, digit in enumerate(number_str):
        if guess[i] == digit:
            cows += 1
            cows_list.append(digit)
            continue
        if guess[i] in number_str and guess[i] not in cows_list:
            bulls += 1
    print(f"{cows} {'cow' if cows == 1 else 'cows'}, {bulls} {'bull' if bulls == 1 else 'bulls'}")
    guess = int(input("Enter a number: "))
    guesses_count += 1

print(f"You made it! The secret number was: {number}")
print(f"It took you {guesses_count} {'attempt' if guesses_count == 1 else "attempts"}")
# Out:
# Welcome to the Cows and Bulls Game!
# Enter a number:  1111
# 0 cows, 0 bulls
# Enter a number:  2222
# 0 cows, 0 bulls
# Enter a number:  3333
# 0 cows, 0 bulls
# Enter a number:  4444
# 0 cows, 0 bulls
# Enter a number:  5555
# 2 cows, 0 bulls
# Enter a number:  5511
# 2 cows, 0 bulls
# Enter a number:  5566
# 3 cows, 0 bulls
# Enter a number:  5561
# 3 cows, 0 bulls
# Enter a number:  5567
# You made it! The secret number was: 5567
# It took you 9 attempts

# %% [markdown]
# ### Sample solution
#
# [Link](https://www.practicepython.org/solution/2014/07/18/18-cows-and-bulls-solutions.html) to sample solution.
